# %%
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# Definir el número de muestras
n_samples = 50

# Crear arrays de ceros para x y y
x = np.zeros((n_samples, 2))
y = np.zeros((n_samples, 2))

# Asignar valores a x[:,0]
x[:, 0] = np.array(list(range(n_samples)))

# Asignar valores a y[:,0] (Corrigiendo el error de sintaxis)
y[:, 0] = 5 * x[:, 0] + np.random.rand(n_samples) * 20

# Crear y ajustar el modelo de regresión lineal
linear_regression = linear_model.LinearRegression()
linear_regression.fit(x, y)

# Obtener los coeficientes y la intersección
w = linear_regression.coef_
b = linear_regression.intercept_

# Imprimir los coeficientes
print("Pendiente (w[0][0]):", w[0][0])
print("Intersección (b[0]):", b[0])

# Realizar predicciones
y_predicted = linear_regression.predict(x)

# Graficar resultados
plt.plot(x[:, 0], y_predicted[:, 0], 'k-', label="Predicción")
plt.plot(x[:, 0], y[:, 0], 'yo', label="Datos originales")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Pendiente (w[0][0]): 4.9632512753507605
# Intersección (b[0]): 12.45956698530945

# %%
y[:,0] = x[:,0]**3+np.random.rand(n_samples)*20
linear_regression.fit(x, y)
y_predicted = linear_regression.predict(x)
plt.plot(x, y_predicted, 'k-')
plt.plot(x,y,'y^')
plt.show()
